# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Importing the Data and Preprocessing EDA

# %%
df = pd.read_csv(r"C:\Users\mobin\DATASIENCE\ML Assignments\STATISTICS\Navie Bayies\SalaryData_Train.csv")
df
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30161 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            30161 non-null  int64
#  1   workclass      30161 non-null  object
#  2   education      30161 non-null  object
#  3   educationno    30161 non-null  int64
#  4   maritalstatus  30161 non-null  object
#  5   occupation     30161 non-null  object
#  6   relationship   30161 non-null  object
#  7   race           30161 non-null  object
#  8   sex            30161 non-null  object
#  9   capitalgain    30161 non-null  int64
#  10  capitalloss    30161 non-null  int64
#  11  hoursperweek   30161 non-null  int64
#  12  native         30161 non-null  object
#  13  Salary         30161 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.2+ MB

# %%
df.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3258

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# age               int64
# workclass        object
# education        object
# educationno       int64
# maritalstatus    object
# occupation       object
# relationship     object
# race             object
# sex              object
# capitalgain       int64
# capitalloss       int64
# hoursperweek      int64
# native           object
# Salary           object
# dtype: object

# %%
# printing unique value counts for each columns
for i in df.columns:
    print(df[i].value_counts())
# Out:
# age
# 31    769
# 36    757
# 33    748
# 34    743
# 37    740
#      ...
# 82      7
# 83      5
# 88      3
# 85      3
# 86      1
# Name: count, Length: 72, dtype: int64
# workclass
#  Private             19213
#  Self-emp-not-inc     2431
#  Local-gov            2014
#  State-gov            1253
#  Self-emp-inc         1049
#  Federal-gov           929
#  Without-pay            14
# Name: count, dtype: int64
# education
#  HS-grad         8268
#  Some-college    5893
#  Bachelors       4503
#  Masters         1558
#  Assoc-voc       1256
#  Assoc-acdm       994
#  11th             941
#  10th             770
#  7th-8th          541
#  Prof-school      532
#  9th              449
#  Doctorate        364
#  12th             358
#  5th-6th          283
#  1st-4th          149
#  Preschool         44
# Name: count, dtype: int64
# educationno
# 9     8268
# 10    5893
# 13    4503
# 14    1558
# 11    1256
# 12     994
# 7      941
# 6      770
# 4      541
# 15     532
# ...

# %%
# Applying Label Encoder for the Data
from sklearn.preprocessing import LabelEncoder

def label_encoder(x):
    for i in x.columns:
        if x[i].dtype == 'object':
            label_encoder = LabelEncoder()
            x[i] = label_encoder.fit_transform(x[i])
    return x

# %%
data = label_encoder(df)

# %%
data
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30154   53          2         12           14              2           3
# 30155   22          2         15           10              4          10
# 30156   27          2          7           12              2          12
# 30158   58          2         11            9              6           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
X = data.drop('Salary', axis = 1)
Y = data['Salary']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.3,random_state=52)

# %% [markdown]
# ## Model Building

# %%
from sklearn.naive_bayes import MultinomialNB

classifer = MultinomialNB()
classifer.fit(X_train,y_train)
# Out:
# MultinomialNB()

# %%
# Predicting the Data

y_pred = classifer.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %% [markdown]
# ## Print Accuracy Score, Confusion Matrix and Classification Report

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.7638458679221906

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[5676,  291],
#        [1615,  489]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.95      0.86      5967
#            1       0.63      0.23      0.34      2104
#
#     accuracy                           0.76      8071
#    macro avg       0.70      0.59      0.60      8071
# weighted avg       0.74      0.76      0.72      8071
